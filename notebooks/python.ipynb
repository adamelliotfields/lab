# %% [markdown]
# # Python

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/aapl.csv')
df.set_index('Month', inplace=True)

plt.figure(figsize=(12,4))
plt.title('AAPL Monthly Price (2022)')
plt.xlabel('Month')
plt.ylabel('Price')
plt.plot(df['Price'])
plt.show()
